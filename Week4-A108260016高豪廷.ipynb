# %%
print"(a)"
# Out:
#   File "<ipython-input-1-83a78c1c0b2e>", line 1
#     print"(a)"
#              ^
# SyntaxError: invalid syntax

# %%
a=1
a
# Out:
# 1

# %%
a='Python'
a
# Out:
# 'Python'

# %%
print(a,id(a))
# Out:
# Python 140451528531000

# %%
x=1
y=x
print(id(x),id(y))
print(x,y)
# Out:
# 10968800 10968800
# 1 1

# %%
0.1+0.1+0.1
# Out:
# 0.30000000000000004

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
a=123
b=123,456
c="Python"

print(a)
print("a=",a)
# Out:
# 123
# a= 123

# %%
print(a,end="")
# Out:
# 123

# %%
print("Bigflower \n Francis")
# Out:
# Bigflower
#  Francis

# %%
print("Bigflower \t Francis")
# Out:
# Bigflower 	 Francis

# %%
a=int(input("Enter your Number:"))
# Out:
# Enter your Number:123

# %%
a+1
# Out:
# 124

# %%
x=[1,2,3]
y=[1,2,3]
print(id(x),id(y))
print(x is y)
print(x==y)
# Out:
# 140450975575496 140450975574152
# False
# True

# %%
x=1
y=[1,2,3]
print(x in y)
# Out:
# True

# %%
x=1
y=[1,2,3]
print(x not in y)
# Out:
# False

# %%
print((2+3*2)*(4-1))
# Out:
# 24

# %%
b=True
print(b,type(b))
num=20
print(num,type(num))
pi=3.14
print(pi,type(pi))
s="Hello"
print(s,type(s))
# Out:
# True <class 'bool'>
# 20 <class 'int'>
# 3.14 <class 'float'>
# Hello <class 'str'>
